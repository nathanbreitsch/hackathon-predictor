# %%
import json
import string
import nltk

# %%
with open('./scrape_data/projects.json','r') as f:
    projects = json.load(f)

# %%
def transform_blob(blob):
    exclude = set(string.punctuation)
    t_blob = ''.join(ch for ch in blob if ch not in exclude)
    t_blob = t_blob.replace('\n','')
    t_blob = t_blob.replace('  ',' ')
    t_blob = t_blob.upper()
    return t_blob

# %%
transform_blob(projects[4]['description'])
# Out:
# 'INSPIRATIONHUMANS SHOULD DO ONLY THOSE THINGS WHICH REALLY INVOLVES USE OF BRAIN AND MUST NOT DO MUNDANE REPETITIVE TASKS CLASSROOM ATTENDANCE IS ONE OF THEM A HUGE TIME WASTER FOR BOTH STUDENTS AND FACULTY WHAT IT DOESFACULTY JUST NEEDS TO TAKE A SNAP OF STUDENTS SITTING IN CLASSROOM AND IT WILL AUTOMATICALLY MARK AND SAVE ATTENDANCE OF STUDENTS IN CLOUD  HOW I BUILT ITAPP USES MS PROJECT OXFORD FACE API FOR IDENTIFYING STUDENTS IN GROUP IMAGE TAKEN BY FACULTYPROFESSOR OF ALL STUDENTS AND SAVES ATTENDANCE RECORD IN CLOUD CHALLENGES I RAN INTOFEELING COLD IN NIGHT REST ALL WAS MANAGEABLE ACCOMPLISHMENTS THAT IM PROUD OFPHOTTENDANCE AS AN ATTENDANCE SOLUTION HAS A DEFINITIVE EDGE OVER OTHER ATTENDANCE TRACKERS FOR EG MOST OF HARDWARE ATTENDANCE TRACKERS EITHER BASED ON RFID CARDS BIOMETRIC THUMB IMPRESSION ETC REQUIRE A HARDWARE PURCHASE INSTALLATION AND MAINTENANCE CHARGES ON THE OTHER PHOTTENDANCE JUST NEEDS TO BE DOWNLOADED AND IS READY TO USE WITH ZERO INVESTMENT OR MAINTENANCE WHAT I LEARNEDCONSTRAINTS ENFORCE CREATIVITY I WANTED TO MAKE A HARDWARE SOLUTION FOR THE SAME BUT SINCE IM NOT THAT STRONG WITH HARDWARE I FOCUSED HOW THE SAME THING CAN BE ACHIEVED BY CODE AND CLOUD AS A RESULT I DEVELOPED A TOTALLY CLOUD BASED SOLUTION IM SURE THERE ARE MANY AREAS WHERE VIRTUALIZATION CAN REDUCE OUR DEPENDENCY ON HARDWAREWHATS NEXT FOR PHOTTENDANCECURRENTLY ITS JUST A PROOF OF CONCEPT APP I PLAN TO EXPAND IT TO MORE GENERAL USE CASES INCLUDING BUT NOT LIMITED TO CLASSROOM ATTENDANCE '

# %%
word_count_dict = {}
for project in projects:
    desc = transform_blob(project['description'])
    words = desc.split(' ')
    for word in words:
        if word in word_count_dict:
            word_count_dict[word] += 1
        else: 
            word_count_dict[word] = 1

# %%
word_count_dict
# Out:
# {'': 349,
#  'DETERMINING': 3,
#  'UPVOTING': 1,
#  'BULLETYOU': 1,
#  'CODE': 72,
#  'HOUSEHOLD': 3,
#  'ALMOST': 14,
#  'THICK': 1,
#  'WASTAGE': 2,
#  'NOSE': 1,
#  'EQUIPMENT': 1,
#  'ALIGNING': 1,
#  'AUTOMATICALLY': 13,
#  'LEARNEDBRING': 1,
#  'REORDER': 1,
#  'QUOTE': 1,
#  'WOMANHOOD': 1,
#  'REQUIRE': 11,
#  'TACKLING': 2,
#  'AFFECT': 2,
#  'FRIENDLYLEARNING': 1,
#  'HABITS': 7,
#  'WANTED': 69,
#  'DESIRED': 5,
#  'PLENTY': 1,
#  'CONTACTHOW': 1,
#  'MAXIMIZE': 3,
#  'SIDEWALK': 1,
#  'SYNCS': 1,
#  'DURING': 31,
#  'HENRY': 1,
#  'RELATES': 1,
#  'ATTEMPTED': 4,
#  'COMPLICATIONS': 1,
#  'HEADBAND': 3,
#  'SUPPLIES': 4,
#  'FEEDBACKCHALLENGES': 1,
#  'CALANDERWHAT': 1,
#  'LATE': 6,
#  'OFDIDNT': 1,
#  'OFCOMBINING': 1,
#  'SOMEONE': 10,
#  'PRODUCT': 28,
#  'PROVOKING': 1,
#  'LEARNEDSOME': 1,
#  'WIKIPEDIA': 7,
#  'DJ': 6,
#  'CIRCUMSCRIBES': 1,
#  'FULLYFUNCTIONING': 1,
#  'ACCENT': 1,
#  'FIGHTING': 4,
#  'CHOOSE': 14,
#  'IPHONETHERE': 1,
#  'MARIO': 1,
#  'SNO': 3,
#  'DIALOGSTARTUP': 1,
#  'INSTAGRAM': 7,
#  'DASH': 1,
#  'TERMINATED': 1,
#  'TROUBLESHOOT': 1,
#  'COMFORTWHAT': 1,
#  'RAPID': 5,
#  'MODELED': 1,
#  'DATA': 199,
#  'BIG': 16,
#  'DOESTHIRD': 1,
#  'NEITHER': 5,
#  'CALL': 7,
#  'EMG': 1,
#  'ELECTRONIC': 2,
#  'WITHCSDLTILEDMAPEDITOR': 1,
#  'CRUNCHED': 1,
#  'AFFILIATION': 1,
#  'DOWHATS': 2,
#  'PATCH': 1,
#  'REPRESENTATIVES': 3,
#  'SOBERING': 1,
#  'ENTITY': 2,
#  'IMPEDANCE': 1,
#  'EMGELECTROMYOGRAPHIC': 1,
#  'STRAIGHT': 3,
#  'WITHJAVASCRIPTPHPMYSQL': 1,
#  'INSTATYPEBIGGER': 1,
#  'BEENSTALK': 1,
#  'KEY': 16,
#  'NAMED': 3,
#  'BUTTON': 11,
#  'RESPECTIVELY': 1,
#  'IMAGES': 29,
#  'DABBLE': 1,
#  'PX': 1,
#  'BIWEEKLY': 1,
#  'DEPENDENCY': 1,
#  'RESPECTFULLY': 1,
#  'OFCRISP': 1,
#  'PHOTOSHOP': 7,
#  'ACCOMPLISHMENTWHAT': 1,
#  'LOBBY': 1,
#  'WASDBASED': 1,
#  'TIMECHALLENGES': 1,
#  'SOOTHING': 1,
#  'RETURNS': 5,
#  'ESFP': 1,
#  'INTENTIONALLY': 1,
#  'ANOTHER': 43,
#  'MASTERS': 1,
#  'LARGE': 26,
#  'MATHEMATICAL': 1,
#  'BOARDSLEEPING': 1,
#  'SPHERO': 1,
#  'JARGON': 1,
#  'UNORGANIZR': 1,
#  'WHICHEVER': 1,
#  'FREQUENTLYACCOMPLISHMENTS': 1,
#  'X': 4,
#  'INTOENSURING': 1,
#  'PRIOR': 3,
#  'HYBRID': 4,
#  'HUMANSSOMETIMES': 1,
#  'PICAMERA': 1,
#  'SONGSHOW': 1,
#  'DOODLER': 1,
#  'POTENTIAL': 19,
#  'PUBLICKEY': 2,
#  'BOARDSEEEDSTUDIO': 1,
#  'SUITABLE': 5,
#  'POWER': 16,
#  'ERRORS': 6,
#  'FIXWHAT': 1,
#  'PLAYWHAT': 2,
#  'FASTRESPONSEREPORTING': 1,
#  'PEBBLEJS': 3,
#  'RACES': 1,
#  'WITHPYTHONPYGAME': 1,
#  'FUSION': 2,
#  'MERCHANDISE': 1,
#  'WAYHOW': 1,
#  'CSSWHATS': 2,
#  'WASTER': 1,
#  'AIRMOUSEAIRMOUSE': 1,
#  'RECIPESINPUT': 1,
#  'DISEASE': 3,
#  'TAGS': 20,
#  'COMPREHENSIVE': 2,
#  'SLAP': 2,
#  'SURVIVAL': 1,
#  'RELEASED': 2,
#  'DIVERSITY': 2,
#  'S20': 1,
#  'UCSC': 3,
#  'COLLECTING': 3,
#  'TABLE': 8,
#  'JOB': 16,
#  'EMPTY': 3,
#  'TOPICS': 3,
#  'HUNDREDS': 3,
#  'COMFORT': 6,
#  'TEACHES': 3,
#  'MOREWHAT': 1,
#  'PLEASING': 5,
#  'DEMO': 5,
#  'FORMAT': 6,
#  'DEFINITELY': 5,
#  'WRESTLE': 1,
#  'FORECAST': 1,
#  'PULSE': 9,
#  'PROPERLY': 11,
#  'ITAS': 1,
#  'SPEEDOUR': 1,
#  'OFTHAT': 4,
#  'DRIVE3D': 1,
#  'LEARNEDMARKI': 1,
#  'EAT': 5,
#  'ESP8266': 1,
#  'TIER': 1,
#  'GEOLOCATIONWHAT': 1,
#  'LIGHTSABER': 1,
#  'RESCUE': 4,
#  'USERFRIENDLY': 2,
#  'JAMES': 2,
#  'INSPIRATIONGIRLS': 1,
#  'WORKING': 69,
#  'MSUNSIGNED': 1,
#  'WIDE': 3,
#  'LISTACCOMPLISHMENTS': 1,
#  'TON': 3,
#  'ROSTER': 1,
#  'PARTICIPATE': 2,
#  'DESCRIBED': 2,
#  'RECEIVE': 15,
#  'HOUR': 4,
#  'FASTENED': 2,
#  'CONVINCE': 1,
#  'SHUTTING': 1,
#  'WRITES': 1,
#  'PROGRAMMERSWHATS': 1,
#  'WIRELESS': 2,
#  'WITHJAVASCRIPTADS': 1,
#  'ENABLES': 2,
#  'TAILED': 3,
#  'DOESCREATES': 1,
#  'CREATES': 6,
#  'ATTRACTIONS': 6,
#  'DIFFICULTACCOMPLISHMENTS': 1,
#  'BEGINING': 1,
#  'WAYPOINTHOW': 1,
#  '75': 2,
#  'INTOBIGGEST': 1,
#  'ADVOCACYACT': 1,
#  'CHANGED': 3,
#  'FABRICWHAT': 1,
#  'FOCUS': 6,
#  'CLASSROM': 1,
#  'UNDERLYING': 2,
#  'SUBPROCESSES': 2,
#  'INTOUSER': 1,
#  'SURVIVE': 2,
#  'HOOTETC': 1,
#  'AXURE': 1,
#  'CHALLENGING': 10,
#  'USEWHATS': 1,
#  'MATH239': 3,
#  'OPTIONAL': 1,
#  'AUTOMATIC': 2,
#  'ENTIRELY': 5,
#  'TRIES': 1,
#  'EXACT': 2,
#  'WEIGHTINGS': 1,
#  'REALDONALDTRUMP': 1,
#  'WORLD': 40,
#  'ESSENTIAL': 3,
#  'FOR': 817,
#  'JS': 3,
#  'POSTING': 3,
#  'PROVIDING': 5,
#  'MAJOR': 21,
#  'JUMPED': 1,
#  'EXTENSION': 13,
#  'GRASP': 1,
#  'SYMBIOSISWHAT': 1,
#  'URINALYSIS': 1,
#  'DEVICESONE': 1,
#  'MARKETWHAT': 1,
#  'DOUBLEVISION': 1,
#  'CARE': 19,
#  '25': 2,
#  'AR': 3,
#  'EDITS': 1,
#  'CLIENTREAD': 1,
#  'SERVER': 56,
#  'PEACE': 1,
#  'CRAZY': 1,
#  'SPREADING': 1,
#  'INSPIRATIONINSPIRED': 2,
#  'GATHERS': 1,
#  'POSSIBLE': 27,
#  'NOISY': 2,
#  'SLEEPWHATS': 2,
#  'SHELTER': 1,
#  'HIGHESTCAN': 1,
#  'VISIBLE': 4,
#  'SKYSCRAPER': 1,
#  'WITHUNITYCGITHUBGIT': 1,
#  'ALONE': 8,
#  'QUADRAFIRE': 1,
#  'DIRE': 1,
#  'STOPPED': 1,
#  'FILESFINALLY': 1,
#  'SPARES': 1,
#  'PULL': 5,
#  'DISABILITIESWHAT': 1,
#  'EASYTOCODE': 1,
#  'INSIGHT': 3,
#  'FURTHER': 22,
#  'PROVISION': 1,
#  'THERMAL': 3,
#  'DIDNT': 14,
#  'SPIRENT': 1,
#  'STOCKTALKWE': 1,
#  'CLOSER': 4,
#  'CIRCUITRY': 1,
#  'STYLE': 6,
#  'COMING': 12,
#  'ELECTRICITY': 1,
#  'ACQUIRE': 3,
#  'FIST': 2,
#  'GENIEWE': 1,
#  'ANYONE': 6,
#  'THOUGHTACCOMPLISHMENTS': 2,
#  'PROFILING': 4,
#  'STATION': 2,
#  'DOESDRONE': 1,
#  'ZETA': 1,
#  'RESPONSIBILITY': 1,
#  'REDESIGN': 1,
#  'JUMPING': 3,
#  'INTOAVOIDING': 2,
#  'CATEGORIZE': 2,
#  'APPCERTIFICATIONPASSWORD': 1,
#  'WINDOW': 2,
#  'PITCH': 7,
#  'WITHNODEJSREACTAMAZONWEBSERVICESBOOTSTRAPWEBPACKGIT': 1,
#  'STRONG': 3,
#  'HARDWARE': 50,
#  'DOESTHEY': 1,
#  'RESPONSEALTHOUGH': 1,
#  'PROCESS': 26,
#  'ENROLLED': 1,
#  'INCENTIVISE': 2,
#  'DEFEATED': 1,
#  'APPLICATIONWE': 1,
#  'OPTIONALLY': 1,
#  'HOYAHACKS': 1,
#  'MANNERCHALLENGES': 1,
#  '6UNSIGNED': 1,
#  'SDKS': 2,
#  'PROCESSES': 5,
#  'NEARPARALYSIS': 1,
#  'FORUM': 2,
#  'SPEAKERS': 1,
#  'PARALYSIS': 1,
#  'DEVICETHE': 1,
#  'RECOMMENDED': 2,
#  'INTORESEARCHING': 1,
#  'TEAMWHAT': 1,
#  'GOOGLES': 4,
#  'WITHHTMLJAVASCRIPTBOOTSTRAP': 1,
#  'THANK': 1,
#  'ISSERVER': 1,
#  'BINGE': 1,
#  'MATCH': 5,
#  'METALS': 1,
#  'EXPERIENCES': 7,
#  'REASON': 4,
#  'ANIMATIONS': 7,
#  'SOLVING': 6,
#  'LEARN': 30,
#  'COMPUTATION': 3,
#  'POPULAR': 7,
#  'AMID': 1,
#  'GAINED': 6,
#  'AIRLINE': 1,
#  'ASKTHE6GODHACKTHE6': 1,
#  'ACCOMPLISHMENT': 10,
#  'ITARGLA': 1,
#  'TODAYS': 1,
#  'VEDAR': 1,
#  'HTTPSWWWASSETSTOREUNITY3DCOMENCONTENT535193D': 1,
#  'ALGORITHMSCHALLENGES': 2,
#  'TRIPLE': 2,
#  'HORIZONS': 1,
#  'DISCUSSING': 1,
#  'PRIORITIZATION': 1,
#  'TRANSFERCHALLENGES': 1,
#  'RELATIONSHIP': 2,
#  'BUDDYFINDERFINDING': 1,
#  'ABSTRACTIONS': 2,
#  'SILLY': 3,
#  'MEMBERS': 23,
#  'PERSIST': 2,
#  'BOOTH': 1,
#  'NOTIFYING': 1,
#  'LANGUAGESCHALLENGES': 1,
#  'LASERWORKING': 1,
#  'PHILANTHROPIC': 1,
#  'BOBBY': 1,
#  '25LIVE': 5,
#  'WITHMETEORJSJQUERY': 1,
#  'KEYWORDS': 3,
#  'OF1': 1,
#  'GUARANTEED': 1,
#  'SENDS': 3,
#  'HACKRICE': 4,
#  'ORIGIN': 1,
#  'YOUVE': 2,
#  'UTILITIESWE': 1,
#  'LEAST': 11,
#  'DOESENCASED': 1,
#  'DETECTOR': 2,
#  'CIRCUIT': 7,
#  'SWIFT': 17,
#  'REUNITED': 1,
#  'INTOWHAT': 1,
#  'YES': 5,
#  'ARRAYSACCOMPLISHMENTS': 1,
#  'CORRESPOND': 2,
#  'RISE': 1,
#  'TEMPORARILLY': 1,
#  'ADDS': 1,
#  'INSPIRATIONABIGAIL': 1,
#  'DJANGO': 2,
#  'HELL': 2,
#  'GETTING': 33,
#  'PROGRAMMINGWHATS': 2,
#  'DOESAIRMOUSE': 1,
#  'REPLACING': 1,
#  'RACIAL': 4,
#  'WEBPAGES': 1,
#  'SCULPTING': 1,
#  'SKETCHY': 1,
#  'JACKET': 4,
#  'ON': 496,
#  'DEADLINE': 2,
#  'COLLECTIVELY': 2,
#  'PREDEFINED': 3,
#  'FOSTER': 2,
#  'DIMENSIONS': 2,
#  'FACEBOOKS': 3,
#  '512': 1,
#  'FIDDLED': 1,
#  'RESEARCHA': 1,
#  'WHOSE': 1,
#  'WORLDWHAT': 1,
#  'TURNS': 3,
#  'PINSHOW': 1,
#  'GRAPHINGHOW': 1,
#  'MINIVEHICLE': 1,
#  'FULLON': 1,
#  'COPYCASTSO': 1,
#  'HIM': 9,
#  'PERSONALIZED': 6,
#  'INVITES': 1,
#  'ENDING': 3,
#  'CONTROLCHALLENGES': 2,
#  'SERIALPRINTLNPOSTING': 1,
#  'CUTOUT': 1,
#  'VALVES': 1,
#  'DOESWHILE': 1,
#  'CIRCUMSTANCES': 1,
#  'PRINTOUTS': 1,
#  'MIRROR': 2,
#  'COMBINES': 2,
#  'ROUTERS': 2,
#  'SUBSCRIPTION': 1,
#  'REOCCURRING': 1,
#  'THAT': 930,
#  'TOUCHED': 1,
#  'THROWING': 1,
#  'BANDACCOMPLISHMENTS': 1,
#  'MEMESHOW': 1,
#  'ROUTES': 2,
#  'WITHPROCESSINGARDUINO': 1,
#  'V1': 1,
#  'ENJOYCHALLENGES': 1,
#  'COMPONENTSWHATS': 1,
#  'CREATED': 46,
#  'INCLUDED': 8,
#  'SMOOTHER': 1,
#  'POLICE': 19,
#  'PROGRAMMATICALLY': 1,
#  'PICKTURETHISPICKTURETHIS': 1,
#  'ELECTRET': 1,
#  'RECIPE': 6,
#  'LIKEPHONE': 1,
#  'EFFORTLESS': 1,
#  'PLANET': 3,
#  'PROTOCOL': 2,
#  'SUPER': 5,
#  'DEEP': 5,
#  'SOON': 6,
#  'TAPPED': 1,
#  'CONCEPT': 15,
#  'GOOGLEMAPSCOREGRAPHICSSYSTEMCONFIGURATIONSECURITYQUARTZCOREOPENGLESIMAGEIOGLKITCORETEXTCORELOCATIONCOREDATACOREBLUETOOTHAVFOUNDATIONACCELERATEMAPKIT': 1,
#  'BRAVE': 1,
#  'SPECIFIED': 2,
#  'PEEKS': 1,
#  'TUT': 1,
#  'HTML5': 3,
#  'PRINTERS': 1,
#  'FURTHERMORE': 8,
#  'ETCSERVER': 1,
#  'SUBCATEGORY': 1,
#  'INTUITIVELY': 1,
#  'GROWTH”': 1,
#  'STRSTRRESPONSE': 2,
#  'WITHUNITYVUFORIAC': 1,
#  'FIRSTHAND': 3,
#  'CONNECTS': 6,
#  'PET': 6,
#  'COMBINE': 3,
#  'INSPIRATIONHIGH': 1,
#  'WORDS': 15,
#  'NOUNS': 1,
#  'OS': 5,
#  'TARGETSBETTER': 1,
#  'JOINT': 1,
#  'PARSES': 5,
#  'REINFORCEMENTMORE': 1,
#  'SENSORMAKERFRONT': 1,
#  'LEANING': 1,
#  'DOESFULLY': 1,
#  'PHOTTENDANCE': 1,
#  'FRIENDSBY': 1,
#  'ENTERTAINING': 2,
#  'LINEUPWE': 1,
#  'MIRE': 1,
#  'COMMUNICATIONS': 1,
#  'STRIPCHALLENGES': 2,
#  'BLINDING': 1,
#  'ILL': 1,
#  'PICK': 8,
#  'IRRECOVERABLEWHAT': 1,
#  'ABLE': 138,
#  'ITHTOO': 1,
#  'LOANS': 1,
#  'EG': 3,
#  'SAMPLETIMEMS': 2,
#  'AMERICAN': 2,
#  'LEARNEDMANY': 2,
#  'SPEAK': 1,
#  '106': 1,
#  'SYSTEMS2': 1,
#  'VIDEO': 39,
#  'VARIOUS': 22,
#  'RIFT': 14,
#  'DEALT': 1,
#  'CATCH': 2,
#  'DISSUADED': 1,
#  'SOLVED': 5,
#  'HEADACHEACCOMPLISHMENTS': 1,
#  'INSPIRATIONACTIVISM': 1,
#  'COOPERATE': 1,
#  'GRADUATE': 1,
#  'APPARATUS': 1,
#  'FUNCTIONALITYWE': 1,
#  'RASPBERRYPI': 2,
#  'CAMERA': 15,
#  'DETECTIONWHAT': 1,
#  'HELPSERVICE': 1,
#  'BECOMING': 4,
#  'ADAM': 1,
#  'ASKS': 4,
#  'CARDIO': 2,
#  'ENVIRONMENT': 17,
#  'INTERCONNECT': 1,
#  'CHICAGO': 1,
#  'DISEASES': 7,
#  'IRREVERSIBLY': 1,
#  'IDEA': 53,
#  'UNIONS': 1,
#  'PLANSTOO': 1,
#  'MADE': 39,
#  'HOST': 3,
#  'RPG': 1,
#  'HOODED': 1,
#  'BIRD': 1,
#  'WHOLE': 19,
#  'SCHOOLMISCHIEU': 1,
#  'UNATTAINABLE': 1,
#  'ACCOUNTWHAT': 1,
#  'TRICKS': 2,
#  'RAVE': 1,
#  'PUNCHUSER': 1,
#  'SLOWED': 1,
#  'EPISODE': 2,
#  'SERVERSIDE': 3,
#  'WATERS': 1,
#  'LEARNEDWORK': 1,
#  'SPORTS': 4,
#  'LISTENS': 1,
#  'PRIMITIVE': 1,
#  'LINKRWE': 1,
#  'DOESFEATURES': 1,
#  'GREENFOOT': 1,
#  '001': 2,
#  'INTENSE': 1,
#  'INSPIRATIONAN': 1,
#  'TRVS': 1,
#  'FACILITATES': 2,
#  'CLEARLY': 5,
#  'ANXIOUS': 2,
#  'TERRAIN': 4,
#  'MESSAGING': 3,
#  'EASILY': 31,
#  'YELLOW': 1,
#  'BOHEMIAN': 1,
#  'PHOTOVERSEPHOTOVERSE': 1,
#  'SOMEWHATWHAT': 1,
#  'BEAMDEVELOPMENTTHE': 1,
#  'COLLEGES': 1,
#  'RFID': 6,
#  'LARAVEL': 1,
#  'EXPLAIN': 4,
#  'ADJUSTABLE': 1,
#  'ASAPHOW': 1,
#  'RELATIVE': 4,
#  'STEAM': 2,
#  'PERISHABLESWE': 1,
#  'OFFICIALLY': 1,
#  'PRETENDING': 1,
#  'STARTEDWHAT': 1,
#  'MIXER': 2,
#  'ONLY': 70,
#  'SEASON': 1,
#  'GND': 1,
#  'DEVELOPMENTCOMPILATION': 1,
#  'INCENTIVE': 2,
#  'CONDITIONING': 1,
#  'OPTIMIZING': 2,
#  'ENTREPRENEUR': 1,
#  'FAIRS': 1,
#  'ABILITIES': 2,
#  'CLICK': 9,
#  'CLOUDPEBBLEWE': 1,
#  'ORDERS': 4,
#  'DOESVROOMVROOM': 1,
#  'RECOMMENDATIONS': 3,
#  'DOZENS': 2,
#  'TINYDUINOSWHATS': 1,
#  'RATES': 7,
#  'MAYBE': 16,
#  'ATTRACTION': 2,
#  'FUNCTIONAL': 14,
#  'REPLICATED': 1,
#  'FULL': 15,
#  'FIRMWARE': 5,
#  'TAG': 12,
#  'CRAFT': 3,
#  'SIGMA': 1,
#  'USWE’RE': 1,
#  'PUSHBULLETCHALLENGES': 1,
#  'TINKERING': 4,
#  'GLOBAL': 5,
#  'MENSTRUAL': 3,
#  'WIT': 1,
#  'MOUNTAIN': 1,
#  'EACH': 107,
#  'MARGIN': 1,
#  'CONSOLIDATES': 1,
#  'PERSONALIZE': 1,
#  'TECHNICIANS': 1,
#  'STORING': 5,
#  'DOESDROPS': 1,
#  'WITHHACKERRANKAPIANDROIDJAVA': 1,
#  'SURVEYSCHALLENGES': 1,
#  'PRIMARILY': 2,
#  'NEARTOTAL': 1,
#  'OBAMAWHAT': 1,
#  'MOSFETS': 1,
#  'DETECTED': 1,
#  'CAR’S': 1,
#  'SELLERS': 3,
#  'DIFFERENT': 96,
#  'MONITOR': 7,
#  'ONHOW': 1,
#  'PHANTPOST': 1,
#  'DEFEND': 1,
#  'CAREGIVER': 1,
#  'DRAWNIF': 1,
#  'ENTERING': 3,
#  'ESTATE': 8,
#  'BLIZZARDS': 1,
#  'PREFECT': 1,
#  'WITHIN': 24,
#  'PASTES': 2,
#  'LESSTHANIDEAL': 1,
#  'PROCESSINGWE': 1,
#  'LEVELS': 13,
#  'ADVICE': 7,
#  'SUGGESTIONS': 4,
#  'ADDRESS': 8,
#  'PHOTOBASED': 2,
#  'BEAUTY': 1,
#  'WORRIED': 2,
#  'AGREEABLE': 1,
#  'BOOT': 3,
#  'REQUESTING': 1,
#  'MARKETING': 2,
#  'LEFT': 8,
#  'ESP': 1,
#  'PULLOVERCHALLENGES': 1,
#  'HEALTHINESS': 1,
#  'INFORMATIONACCOMPLISHMENTS': 1,
#  'ACCOMPLISHMENTSIT': 1,
#  'LOOSEN': 2,
#  'WED': 3,
#  'RESPONSIBILITIES': 1,
#  'PROJECTA': 2,
#  'SYSTEM': 63,
#  'LOCATORCREATING': 1,
#  'INSTANT': 1,
#  'EVENTUAL': 1,
#  'SUCCESSFULLY': 4,
#  'RIGHTWHAT': 2,
#  'IDEATRIVIA': 1,
#  'HEAR': 6,
#  'MATERIALIZE': 1,
#  'OTHERTHE': 1,
#  'VAUGHAN': 1,
#  'SPEED': 7,
#  'PLAID': 1,
#  'INPUT': 27,
#  'RETAIL': 5,
#  'PARICLE': 1,
#  'FINDMEWORKING': 1,
#  'ROUND': 2,
#  'SEWING': 2,
#  'JUNIORS': 1,
#  'PROGRAMING': 1,
#  'BEE': 1,
#  'ITEMS': 12,
#  'LEARNEDLOTS': 2,
#  'HARDERMORE': 1,
#  'EASEOFUSE': 1,
#  'PUMPED': 2,
#  'ITTECHNOLOGIES': 1,
#  'REALWORLD': 1,
#  'LISP': 1,
#  'QUICKBOOKS': 1,
#  'CATALOGUE': 1,
#  'ITGIVEN': 1,
#  'PWHATS': 1,
#  'VAGINAL': 1,
#  'INTRODUCTION': 1,
#  'TRANSLATING': 1,
#  'MARKET': 15,
#  'NEXT': 196,
#  'GAVE': 4,
#  'REACTION': 1,
#  'INCLUSION': 1,
#  'S3': 2,
#  'CLIPBOARDS': 1,
#  'COINS': 1,
#  'DECREASE': 1,
#  'WITHHTMLCSSJAVASCRIPTCHROME': 1,
#  'UNFORTUNATELY': 3,
#  'CALLED': 8,
#  'INSPIRATIONTHROUGHOUT': 1,
#  'OVERWEIGHT': 1,
#  'LEARNEDFEDEX': 1,
#  '36HOUR': 1,
#  'UNUSABLEACCOMPLISHMENTS': 1,
#  'DISCOMFORT': 2,
#  'PORNWHATS': 1,
#  'CALCULUS': 2,
#  'REPORTING': 2,
#  'GUIHOW': 1,
#  'DURATION': 3,
#  'COATED': 1,
#  'ROUTERSWHAT': 1,
#  'PHOTOSHOPCHALLENGES': 2,
#  'TIMEJAMESI': 1,
#  'GAPS': 1,
#  'CLOSED': 2,
#  'ACQUIRING': 1,
#  'LOUD': 1,
#  'CHAOS': 2,
#  'CRASHES': 1,
#  'LOGISTICS': 1,
#  'DINA': 1,
#  'SPEEDY': 1,
#  'RACETRACK': 2,
#  'TWENTY': 2,
#  'IMPACTFUL': 2,
#  'CAVE': 1,
#  'CONCEPTSWHAT': 1,
#  'CIRCLE': 1,
#  'FACILITY': 1,
#  'INCREDIBLY': 4,
#  'HEROKU': 1,
#  'FIREBASEFETCHING': 1,
#  'AVOIDING': 1,
#  'HELP': 85,
#  'WAVE': 5,
#  'ROTATED': 1,
#  'USE': 160,
#  'SPEAKING': 1,
#  'DOESPATIENTS': 1,
#  'BOUNCE': 1,
#  'MUSE': 4,
#  'WITHJAVAPHPJAVASCRIPTJSOUPHTMLCSS': 1,
#  'KFTH': 1,
#  'AVENUE': 1,
#  'TENSORFLOW': 1,
#  'WAYWHAT': 1,
#  'STREAMLINE': 1,
#  'INSPIRATIONBASED': 1,
#  'OVERVIEW': 3,
#  'SKY': 11,
#  'BEACON': 3,
#  'IMAGINE': 3,
#  'INSPIRATIONBURNING': 1,
#  'ADDED': 16,
#  'WITHPYTHONNODEJSAZUREHTML5CSS3JAVASCRIPT': 1,
#  'ANALYSE': 3,
#  'DECREASING': 2,
#  'FREE': 8,
#  'COHESIVE': 1,
#  'SLEEPING': 6,
#  'NICETHIS': 1,
#  'CODES': 7,
#  'ATTENDANCE': 8,
#  'SOFT': 1,
#  'INSPIRATIONCHILDREN': 1,
#  'STATUSWHAT': 1,
#  'BIGBUT': 1,
#  'EXTERNAL': 3,
#  'VIRAL': 2,
#  'LIST': 20,
#  'TROUBLESHOOTING': 2,
#  'INTERFACING': 2,
#  'KEEP': 25,
#  'ASSIGNED': 2,
#  'OVERHEAD': 3,
#  'TYPED': 1,
#  'PLUGINS': 1,
#  'CLEAN': 15,
#  'ROWERS': 2,
#  'GRAPHSTHE': 1,
#  'STATED': 1,
#  'VEHICLES': 3,
#  'PLATFORMWHAT': 1,
#  'OVERLY': 1,
#  'ACCOMPLISHMENTS': 33,
#  'SENSOR': 31,
#  'EXTRACTS': 1,
#  'LEDRESS': 1,
#  'DEVELOPEDACCOMPLISHMENTS': 1,
#  'MOBILE': 55,
#  'SWITCHED': 1,
#  'MAINFEED': 1,
#  'ACCELERATING': 1,
#  'HOPE': 26,
#  'RESPONSES': 5,
#  'BIGPICTUREWE': 1,
#  'INSTEAD': 16,
#  'MAPKIT': 1,
#  'RADIOLOGY': 1,
#  'SUBMISSION': 4,
#  'COCOS2DOBJC': 1,
#  'FLAT': 1,
#  'HEARBEAT': 1,
#  'SOLVERWED': 1,
#  'ITMESPEAK': 1,
#  'HTTPSYOUTUBEUWCDTLGYKJG': 1,
#  'MAINTAINS': 1,
#  'LEARNEDPYTHON': 1,
#  '531THE': 1,
#  'SCREENHARDWARE': 1,
#  'RICH': 1,
#  'YOUEVERYTHING': 1,
#  'LASTS': 1,
#  'SOLDERED': 1,
#  'SHARING': 8,
#  'ASSAULTIN': 1,
#  'DOESCHOPINS': 1,
#  'SCRIPTING2': 1,
#  'FRIENDSHIPS': 1,
#  'STICK': 2,
#  'TWEAKS': 1,
#  'APPLICATIONALL': 1,
#  'MAYA': 1,
#  'DESCRIPTIVE': 3,
#  'ARMBANDS': 1,
#  'ONE': 123,
#  'PAINTS': 1,
#  'SMARTWATCHES': 1,
#  'BEAST': 2,
#  'INSPIRATIONIMPROVING': 1,
#  'FRIENDSCLARIFAI': 1,
#  'SWISS': 3,
#  'QUARTER': 3,
#  'IF': 90,
#  'SDKCREATING': 1,
#  'COLLAR': 1,
#  'PREDICT': 4,
#  'LEARNEDHELPING': 1,
#  'LATER': 10,
#  'HOURSWHAT': 1,
#  'OFINTERACTIVE': 2,
#  'RUNTIME': 1,
#  'CAR': 6,
#  'STABLE': 3,
#  'FIELDS': 1,
#  'STRONGLY': 3,
#  'LISTS': 2,
#  'EMAILMOBILE': 1,
#  'CEO': 1,
#  'BEACHSIDE': 1,
#  'CENSORING': 1,
#  'DUST': 1,
#  'REASONS': 3,
#  'KNACKERED': 1,
#  'BLOCKS': 2,
#  'OFTHINKING': 1,
#  'RESOLUTIONS': 1,
#  'AWAY': 12,
#  'TOPROVIDE': 1,
#  'TWITTERS': 1,
#  '15': 4,
#  'STRIPWHATS': 1,
#  'DOESUPLOADS': 1,
#  'SETBACK': 1,
#  'SOOTHE': 1,
#  'LACK': 16,
#  'COMPLEX': 9,
#  'HACKATHONWHAT': 1,
#  'WANTDEVELOPMENTIN': 1,
#  'SPAWN': 2,
#  'PROBLEMACCOMPLISHMENTS': 1,
#  'IMMERSIVE': 4,
#  'PACKS': 1,
#  'CRYPT': 2,
#  'PROGRAMMABLE': 1,
#  'SELL': 9,
#  'BALL': 4,
#  'REKIA': 1,
#  'MOMENTWHAT': 1,
#  'SESSION': 1,
#  'ADDITIONAL': 8,
#  'DAYWHAT': 1,
#  'HAND': 13,
#  'ITBY': 2,
#  'GPUJSMORE': 1,
#  'HIGHLIGHTS': 1,
#  'URGENT': 3,
#  'ENTERPRISE': 2,
#  'SCIENCE': 12,
#  'OR': 184,
#  'PERSONALISED': 1,
#  'GUARDIANOF': 1,
#  'ENABLE': 1,
#  'SHOOT': 1,
#  'TOWARD': 2,
#  'FAILURE': 1,
#  'UNCORRUPTED': 1,
#  'FAULTY': 1,
#  'THOUGH': 8,
#  'LOCATION': 31,
#  'MUSICAL': 3,
#  'HACKATHON': 48,
#  'UGLY': 1,
#  'FEATURES': 40,
#  '1HUNDREDMONETARY': 1,
#  'BEFORECROSSPLATFORMPLATFORM': 1,
#  'DOESSIMPLY': 1,
#  'SIGNSPEAKSWERE': 1,
#  'FRAMEWORKWHAT': 1,
#  'REDESIGNING': 1,
#  'INTERCONNECTED': 1,
#  'INFECTIONS': 1,
#  'SCREW': 1,
#  'ENHANCED': 1,
#  'WINS': 1,
#  'DRAPE': 1,
#  'HUGE': 10,
#  'BLESSING': 1,
#  'DOCUMENTS': 1,
#  'STRAP': 1,
#  'SHOULDNT': 1,
#  'UNUSED': 2,
#  'DIVERSE': 3,
#  'ARTICLE': 4,
#  'WINNERTHE': 1,
#  'HERE': 10,
#  'INTOTOO': 1,
#  'FORTUNATELY': 1,
#  'ENTRIES': 2,
#  'ATTENDS': 2,
#  'REACT': 1,
#  'NATIONAL': 1,
#  'BUNCH': 2,
#  'DANCEYOURTUNE1': 1,
#  'PARTIAL': 1,
#  'SIGNING': 1,
#  'LESSER': 1,
#  'CHROMECASTCONTENT': 1,
#  'EXTREMELY': 19,
#  'ENOUGHTHEN': 1,
#  'POSSIBLY': 8,
#  'FINELY': 1,
#  'ENGINEERED': 1,
#  'GEMS': 2,
#  'THEYVE': 2,
#  'HYDROQUEBEC': 1,
#  'POSSIBILITIES': 6,
#  'INTOLANGUAGE': 1,
#  'CODING': 18,
#  'INSPIRATIONSMALL': 1,
#  'COMPUTE': 4,
#  'DOESSENSEABILITY': 1,
#  'ANOTHERS': 1,
#  'PROVIDESHOW': 1,
#  'MECHANIC': 2,
#  'PACKET': 3,
#  'IMITATE': 1,
#  'OFIVE': 1,
#  'ALTHOUGH': 9,
#  'OVERWHELM': 1,
#  'HIKING': 1,
#  'AFFORD': 1,
#  'SIMULATOR': 1,
#  'CLEANLY': 1,
#  'ITXCODE': 1,
#  'GENEROSITY': 1,
#  'KART': 1,
#  'STATEMENTS': 3,
#  'PAIR': 4,
#  'VIBRATORS': 2,
#  'TRAUMA': 1,
#  ...}

# %%
word_order_dict = {}
words_counted = [word for word in word_count_dict.keys() if word_count_dict[word] > 10]
len(words_counted)
# Out:
# 745

# %%
words_counted = sorted(words_counted)
num_words = len(words_counted)

# %%
for i in range(0, len(words_counted)):
    word_order_dict[words_counted[i]] = i

# %%
def transform_winner(winner):
    if(winner):
        return 1
    else:
        return 0

# %%
data_output = []
for project in projects:
    word_vec = [0] * num_words
    words = transform_blob(project['description']).split(' ')
    for word in words:
        if word in word_order_dict:
            word_vec[word_order_dict[word]] += 1
    
    data_output.append({
            'hackathon_id': project['hackathon_id'],
            'winner': project['winner'],
            'word_vec': word_vec
        })

# %%
with open('./scrape_data/data_output.json', 'w') as f:
    json.dump(data_output, f)

# %%
transform_w
