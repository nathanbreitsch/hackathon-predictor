# %%
import json
import string
import nltk
import pickle

# %%
with open('./scrape_data/projects.json','r') as f:
    projects = json.load(f)

# %%
def transform_blob(blob):
    exclude = set(string.punctuation)
    t_blob = ''.join(ch for ch in blob if ch not in exclude)
    t_blob = t_blob.replace('\n','')
    t_blob = t_blob.replace('  ',' ')
    t_blob = t_blob.upper()
    return t_blob

# %%
transform_blob(projects[4]['description'])
# Out:
# 'INSPIRATIONHUMANS SHOULD DO ONLY THOSE THINGS WHICH REALLY INVOLVES USE OF BRAIN AND MUST NOT DO MUNDANE REPETITIVE TASKS CLASSROOM ATTENDANCE IS ONE OF THEM A HUGE TIME WASTER FOR BOTH STUDENTS AND FACULTY WHAT IT DOESFACULTY JUST NEEDS TO TAKE A SNAP OF STUDENTS SITTING IN CLASSROOM AND IT WILL AUTOMATICALLY MARK AND SAVE ATTENDANCE OF STUDENTS IN CLOUD  HOW I BUILT ITAPP USES MS PROJECT OXFORD FACE API FOR IDENTIFYING STUDENTS IN GROUP IMAGE TAKEN BY FACULTYPROFESSOR OF ALL STUDENTS AND SAVES ATTENDANCE RECORD IN CLOUD CHALLENGES I RAN INTOFEELING COLD IN NIGHT REST ALL WAS MANAGEABLE ACCOMPLISHMENTS THAT IM PROUD OFPHOTTENDANCE AS AN ATTENDANCE SOLUTION HAS A DEFINITIVE EDGE OVER OTHER ATTENDANCE TRACKERS FOR EG MOST OF HARDWARE ATTENDANCE TRACKERS EITHER BASED ON RFID CARDS BIOMETRIC THUMB IMPRESSION ETC REQUIRE A HARDWARE PURCHASE INSTALLATION AND MAINTENANCE CHARGES ON THE OTHER PHOTTENDANCE JUST NEEDS TO BE DOWNLOADED AND IS READY TO USE WITH ZERO INVESTMENT OR MAINTENANCE WHAT I LEARNEDCONSTRAINTS ENFORCE CREATIVITY I WANTED TO MAKE A HARDWARE SOLUTION FOR THE SAME BUT SINCE IM NOT THAT STRONG WITH HARDWARE I FOCUSED HOW THE SAME THING CAN BE ACHIEVED BY CODE AND CLOUD AS A RESULT I DEVELOPED A TOTALLY CLOUD BASED SOLUTION IM SURE THERE ARE MANY AREAS WHERE VIRTUALIZATION CAN REDUCE OUR DEPENDENCY ON HARDWAREWHATS NEXT FOR PHOTTENDANCECURRENTLY ITS JUST A PROOF OF CONCEPT APP I PLAN TO EXPAND IT TO MORE GENERAL USE CASES INCLUDING BUT NOT LIMITED TO CLASSROOM ATTENDANCE '

# %%
word_count_dict = {}
for project in projects:
    desc = transform_blob(project['description'])
    words = desc.split(' ')
    for word in words:
        if word in word_count_dict:
            word_count_dict[word] += 1
        else: 
            word_count_dict[word] = 1

# %%
word_count_dict
# Out:
# {'': 6047,
#  'BETZPIMP': 1,
#  'LEVEL': 444,
#  'QUICKENS': 1,
#  'QUIRKI': 1,
#  'FAILEDDONTFAILBAD': 1,
#  'WITHANDROIDSQLITEJAVAXML': 1,
#  'DARE': 9,
#  'JSBIN': 1,
#  'მეგობრეთან': 1,
#  'INDICATES': 17,
#  'RELEVANTWHAT': 2,
#  'PASSWORD': 90,
#  'WITHFORDQUALCOMMIOSANDROIDMAGNETTHETA': 1,
#  'BORNI': 1,
#  'ANYONE’S': 1,
#  'ANKITK': 1,
#  'FIREFOXOS': 1,
#  'ВЫПУЩЕННЫХ': 1,
#  'EXPEDIENTLY': 1,
#  'JAVABACKED': 1,
#  'მიიღებთამასთანავე': 1,
#  'ПРОИЗВОДСТВА': 1,
#  'CẤP': 1,
#  'BRIAN': 15,
#  'FLURRY': 1,
#  'НЕТ': 3,
#  'QUESTIONSSTUDIES': 1,
#  'SORENSON': 1,
#  'PREESCOLAR': 1,
#  'IMAGENESWHATS': 1,
#  'WATERGUN': 1,
#  'SALESFORCEEVERY': 1,
#  'KARMAHE': 1,
#  'BITEXTCOM': 1,
#  'VISITBY': 1,
#  'RESCALING': 1,
#  'PHONAR': 1,
#  'ОБЪЕКТ': 2,
#  'RETHINKING': 1,
#  'EXTRACTING': 23,
#  'DROWSY': 4,
#  'SPONGOAPP': 1,
#  'PODCASTS': 5,
#  'ТОЧКАХ': 1,
#  'STOCKED': 1,
#  'ALGORITHMROUTE': 1,
#  'THROUGHTHIS': 1,
#  'INTOALTHOUGH': 3,
#  'NECKPIECE': 1,
#  'RECIPEINAPP': 1,
#  'TRANQUILITY': 1,
#  'CONSCIENTIOUS': 1,
#  'PLAYLISTCHALLENGES': 1,
#  'CAFFEINESOLVING': 1,
#  'CONSUME': 24,
#  'EQUALITY': 8,
#  '414': 1,
#  'DASHBOARDIN': 1,
#  'ACCURACY': 84,
#  'ДИАГРАММЫ': 1,
#  'SAWING': 1,
#  'STANDOUTS': 1,
#  'AIR—OR': 1,
#  'GOOGLELIKE': 1,
#  'ANNIVERSARY': 3,
#  '4000': 6,
#  'CONSULTATIONCURRENT': 1,
#  'FREESUBSCRIPTION': 1,
#  'FELLOWEVAN': 1,
#  'STRAND': 1,
#  'UPBEATUPBEAT': 1,
#  'ONBOARDME': 1,
#  'FLEET”': 3,
#  'LEARNEDLESS': 1,
#  'MADEGITHUB': 1,
#  'FULLINTEGRATION': 1,
#  'HUMANITY': 15,
#  'MADEPARTICIPIN': 1,
#  'მოტორი': 1,
#  'FUNCTIONWE': 2,
#  'REALITY': 314,
#  'ДОБИ': 1,
#  'INPUTACCOMPLISHMENTS': 1,
#  'KEYACCOMPLISHMENTS': 1,
#  'CONOCEN': 1,
#  'ENERGYWHAT': 1,
#  'UPR': 1,
#  'CONTRIBUTIONTHE': 1,
#  'RESEARCHWHAT': 1,
#  'ლაივ': 2,
#  'POSTIVE': 1,
#  'WORKWHEN': 2,
#  'STUDIOFOR': 1,
#  'ПЕРСОНАЛЬНЫЙ': 1,
#  'SNAPPY': 5,
#  'TAPWE': 1,
#  'P2PDISTRIBUTEIO': 1,
#  'GIMME5PY': 1,
#  'LIKINGNOT': 1,
#  'DSLRSI': 1,
#  'WALLYS': 1,
#  'LEANED': 3,
#  'MATEJCZYK': 1,
#  'HUNTINGWHAT': 1,
#  'EYE': 86,
#  'ПЕРЕСАДОЧНОГО': 1,
#  'WITHJAVASLICK2DTWITTER': 1,
#  'NIVEL': 5,
#  'CHOICEDFROM': 1,
#  'CALLRELEVANT': 1,
#  'FLEXIBLY': 1,
#  'PICKUP': 50,
#  'DÍAA': 1,
#  'XIAO': 2,
#  'BETTERS': 2,
#  'ACHIEVEMENTONCE': 1,
#  '4ხელმისაწვდომი': 1,
#  'STRUGGLESHOW': 1,
#  'პრაქტიკულად': 1,
#  'TROLLING': 3,
#  'JORDAN': 1,
#  'CURCIO': 1,
#  'REFRIGERATORVIRTUAL': 1,
#  'TRANSLATIONS': 10,
#  'JS': 60,
#  'SPEECHTOTEXTTHE': 1,
#  'RATE•': 1,
#  'EVENTUALLYSEAMLESS': 1,
#  'БЫЛИ': 2,
#  'IBECON': 1,
#  'SASCHAROTHELIVEDE': 1,
#  'RECYCLEMEFINISH': 1,
#  'DOUBLEVISIONOPTIMIZE': 1,
#  'COMPANYORGANIZATIONTHE': 1,
#  '2PLY': 1,
#  'PROMETHEUS': 1,
#  'გადავიდეს': 2,
#  'ПРАВИЛЬНОСТЬ': 1,
#  'GUHMANCHESTERMAKE': 1,
#  'WHERES': 2,
#  'INSTANTWEB': 1,
#  'LOGAR': 2,
#  'ЦЕЛЕВЫМИ': 1,
#  'WEBFORMSHTTPSGITHUBCOMCODEFORPAKISTANCRIMEREPORTINGMAP': 1,
#  'TABLEACCOMPLISHMENTS': 1,
#  'WITHGROOVYONGRAILSHTML': 1,
#  'KALICHOSAUDIO': 1,
#  'СЛУЧАЕ': 4,
#  'OFFOR': 2,
#  '3BREAKING': 1,
#  'GODS': 9,
#  'SOCIOECONOMICS': 1,
#  'TRÁNSITO': 1,
#  'WITHSWIFTIOS': 2,
#  'ETCLIMIT': 1,
#  'INFLUENCEHOW': 1,
#  'NOTICEABLE': 7,
#  'TUNNELING': 1,
#  'WITHPYTHONTWILIOFLASKNGROK': 1,
#  'TRYPS': 1,
#  'IDES': 5,
#  'ЛЕГКО': 5,
#  'URGENTLY': 3,
#  'EFFORTSMOTIVATIONMONEY': 1,
#  'ავტომობილის': 1,
#  'GLITCH': 2,
#  'JOURNE': 1,
#  'გადასახადს': 1,
#  'MEALTHE': 1,
#  'UNPRODUCTIVE': 1,
#  'REPLACES': 16,
#  'MEMBERSAN': 1,
#  'PHOTOCHALLENGES': 1,
#  '90Х': 1,
#  '“PRODUCT”': 1,
#  'CONCEPTION': 4,
#  'BOOKIE': 2,
#  'DISCLOSE': 1,
#  'SPOIL': 1,
#  'LEGIT': 3,
#  'APIWHATS': 23,
#  'AWESOMEGITHUBSOURCETREE': 1,
#  'SER': 34,
#  'DESIGNHARD': 1,
#  'ZUMO': 6,
#  'SAVEMEWE': 1,
#  'DICTATED': 3,
#  'DEVELOPERSPREVIOUS': 1,
#  'HOURLY': 13,
#  'KURANGNYA': 3,
#  'NEIGHBOURHOOD': 6,
#  'MOOSIC': 1,
#  '3000208': 2,
#  'TRACKERWEAR': 1,
#  'ARCHIVE': 9,
#  'MICSPEAKER': 1,
#  'PUZZLE': 49,
#  'HILARIOUS': 7,
#  'WITHHTML5CSS3JAVASCRIPTPARSE': 1,
#  'BUILTABOUT': 1,
#  'FRANK': 2,
#  '“MYBUENOSAIRES”': 1,
#  'FEATURESMATCHING': 1,
#  'EMAILMOBILE': 1,
#  'JAVACOMBINING': 1,
#  'ПРИЛОЖЕНИЯПРОКЛАДКА': 1,
#  'VARRER': 1,
#  'სენსორების': 2,
#  'ACCESSORY': 6,
#  'APPLICATIONSAPP': 1,
#  'SERVERWHENEVER': 1,
#  'TUNTUTAN': 1,
#  'AUTOMATIZED': 2,
#  'CSTINSPIRATIONTECH': 1,
#  'CINCINNATI': 2,
#  'SITESO': 1,
#  'OV7670': 1,
#  'STORYTELLER': 3,
#  'ROTARY': 6,
#  'DISCOUNTS': 36,
#  'ENROUTE': 2,
#  'FEEDBACKTARGET': 1,
#  'PHOTOJOURNAL': 1,
#  'VALUE1': 1,
#  'DINING': 45,
#  'AWEFUL': 1,
#  'TOPTRUMPS': 1,
#  'DAD': 19,
#  'GOVERNMENTAL': 3,
#  'CUERPO': 1,
#  'INTEGRATIONIMPROVE': 1,
#  'MINIMALISTIC': 10,
#  '2012': 26,
#  'COACHERS': 1,
#  'WCZORAJ': 2,
#  'ADMINBY': 1,
#  'STATICALLYTYPED': 1,
#  'IMPAIRED': 66,
#  'DISABLED': 29,
#  'წამი': 3,
#  'SKYROCKETINGWE': 1,
#  'ბრაუზერით': 1,
#  '1980': 2,
#  'CARTOGRAPHIC': 1,
#  'INSPIRATIONHAVE': 11,
#  'TEMPTS': 1,
#  'DISAMPAIKAN': 1,
#  'COMMITMENTS': 1,
#  'АНКЕТЫ': 1,
#  'თავისუფლებაა': 1,
#  'DEMANDOPEN': 1,
#  'EXPERIMENT': 31,
#  'CARDBOARDWHAT': 1,
#  'RESPONSEI': 1,
#  'CAREFUL': 25,
#  'DRAWS': 23,
#  'BLUECOVE': 1,
#  '14TH': 1,
#  'EXPERIENCECREATE': 1,
#  'CUPID': 2,
#  'TXTCOIN': 1,
#  'ENDBOOTSTRAP': 1,
#  'COOLWHATS': 3,
#  'ბევრჯერ': 1,
#  'WAPO': 1,
#  'USERNAMEVALUE': 2,
#  'AGREAT': 1,
#  'ACABAS': 1,
#  'Q1': 1,
#  'SEDENTARY': 2,
#  'SYMOND': 1,
#  'MICROCOMPUTER': 3,
#  'CKEDITOR': 2,
#  'NEEDWHATS': 3,
#  'ОТКАЖУТСЯ': 1,
#  'GUESS': 56,
#  'GEMMA': 2,
#  'HTTPSWWWDROPBOXCOMSH3R1OY48Q8LT9XWVAACCR3JKODO3P1RBVOASK5XRA2014101820182326MP4DL0THE': 1,
#  'RECYCLO': 1,
#  'LENSES': 3,
#  'ჩეთი': 1,
#  'STEPPED': 2,
#  'ИСПОЛЬЗУЕМ': 1,
#  'MCD': 2,
#  'BLUETOOTHOUR': 1,
#  'SNAGGEDWHAT': 1,
#  'BL': 1,
#  'RUNWHAT': 1,
#  'РАСПРЕДЕЛЯЮЩИЕ': 1,
#  'SCARING': 2,
#  'MICROVOLUNTEERING': 1,
#  'POINTELIST': 1,
#  'PERSON’S': 6,
#  '‘NAG’': 1,
#  'CENTRALSERVERSERVERJS': 1,
#  'NARB': 1,
#  'MODIFICATIONOUTPUTBASIC': 1,
#  'OPENBR': 1,
#  'LAUNDRY': 10,
#  'JGRASP': 2,
#  'STUMPED': 6,
#  'TREASURES3': 1,
#  'GAUNTLETHOW': 1,
#  'MODULESALSO': 1,
#  'AFIN': 3,
#  'BEATING': 5,
#  'GOIPROPERTY': 1,
#  'PRODUCTIVEUSE': 1,
#  'MEDIAACCOMPLISHMENTS': 1,
#  'BATTLEBOTWE': 1,
#  'CENÁRIOS': 2,
#  'INTUITWE': 1,
#  'PROMPTING': 6,
#  'CHASING': 3,
#  'CREATER': 1,
#  'PANDAS': 10,
#  'ГРАЖДАНИНТЕРАКТИВНАЯ': 1,
#  'HTTPVIDOSMYBLUEMIXNETQPRIME20MININSTER20OF20INDIAHOW': 1,
#  '“SUGGESTING': 1,
#  'LEGALZOOM': 2,
#  'CSNERMAN': 1,
#  'SPEEDACCOMPLISHMENTS': 1,
#  'MOUNTAINDESERT': 1,
#  'ჩაბარებული': 1,
#  'PARCERIA': 3,
#  'AEROSPACE': 2,
#  'REPLETE': 1,
#  'NONBASIC': 1,
#  'LISTA': 6,
#  'НОВЫХ': 1,
#  'PARTWE': 1,
#  'GOFOR': 1,
#  'FLOWCHARTRMAKING': 1,
#  'IFTTTLIKE': 1,
#  'თავისუფალ': 3,
#  'MYOPIA': 1,
#  'INSTAFLIGHT': 2,
#  'APPLICATIONIM': 2,
#  'SCLEROSIS': 3,
#  'ჩაკოპირებული': 1,
#  'COUNTERPART': 1,
#  'PONDER': 1,
#  'FIREFIGHTERS': 8,
#  'DEVUNINPUTXDOTOOL': 1,
#  'STORAGEFOR': 1,
#  'PIN': 98,
#  'DETRIMENTAL': 2,
#  'INTEGRATION': 299,
#  'YOUBECAUSE': 1,
#  'PROMOTIONSSHIPPING': 1,
#  'PRECISEHERE': 1,
#  'SERVICELIKE': 1,
#  'დამატებას': 2,
#  'დაყოფილია': 1,
#  'BIRDLY': 1,
#  'BACKENDOUR': 2,
#  'MYOCHALLENGES': 1,
#  'MCWHARTERS': 1,
#  'SAFERWHAT': 3,
#  'SERVICECONTACT': 1,
#  'LOANERS': 2,
#  'JOURNALARDUINO': 1,
#  'S27A': 1,
#  'DETAILSACCOMPLISHMENTS': 1,
#  'WITHANDROIDSTUDIOFLIRSDK': 1,
#  'ПРО': 5,
#  'INTOAUTHENTICATE': 1,
#  'BRANDON': 4,
#  'PROPOSES': 5,
#  'TRICKERYWHATS': 1,
#  'PLEASESOME': 1,
#  'CASE': 300,
#  'WITHPHPNODEJSEXPRESSJSCURLMONGODBANGULARJS': 1,
#  'CATERING': 3,
#  'PROSES': 8,
#  'MEMPERTIMBANGKAN': 1,
#  'ONCEMEDICAL': 1,
#  'ISWAGERIZE': 1,
#  'TRAVÉS': 18,
#  'INCLUDESSPECIFYING': 1,
#  'SPENCE': 8,
#  'VANDENBERG': 1,
#  'DEFINING': 11,
#  'TRANS': 2,
#  'ZHOUC': 1,
#  'PATERNITY': 1,
#  'ROBOTWHATS': 1,
#  'SIDEPATHFINDING': 1,
#  'COMPLETEUSE': 1,
#  'AGAINWHAT': 1,
#  'ВІДКРИТИЙ': 1,
#  'WITHHTMLJAVASCRIPTCSSPHPAPI': 1,
#  'LOSSAUTO': 1,
#  'პოლიციასამედიცინო': 1,
#  'SAFENESS': 1,
#  'OPENID': 2,
#  'MAKINGVOTING': 1,
#  'USERDRIVEN': 1,
#  'DRINK2ND': 1,
#  'INSTANTE': 1,
#  'OUMAR': 2,
#  'ოფლაინ': 2,
#  'JUGADOR': 1,
#  'FORMULATHE': 1,
#  'WINDOWED': 1,
#  'HORIZONTAL': 12,
#  'BOILERMAKECHALLENGES': 1,
#  'LEARNINGWE': 1,
#  'CRITRICAL': 1,
#  '885MPH': 1,
#  'EXPERIENCE3': 1,
#  'MICROUSB': 2,
#  'NAUTICAL': 1,
#  'PIKLIST': 3,
#  'FANCYA': 1,
#  'მის': 19,
#  'SELF”': 1,
#  'CHANGEDHOW': 1,
#  'WHEELSTECHNOLOGIES': 1,
#  'ADVISORSNO': 1,
#  'WATERERTHE': 1,
#  'GHANA•': 1,
#  'COMMUNITYს': 1,
#  'STORESCREEN': 1,
#  'FEATURESCHAT': 1,
#  'GENDERQUEER': 1,
#  'ENTRÉEFOLLOW': 1,
#  'BEND': 5,
#  'QUERÍAMOS': 1,
#  'WITHANDROIDGRADLE': 1,
#  'HTTPSCLOUDANSWERSCONCIERGEHEROKUAPPCOM': 1,
#  'ЮРИДИЧНІ': 1,
#  'SMALLYELLOW': 1,
#  'GASES': 1,
#  'ПЕРСОНАЛЬНЫХ': 1,
#  'PREESCOLARES': 1,
#  'PEBBLEMAZE': 1,
#  'CONTACTORFIGURE': 1,
#  'BEER': 22,
#  '331': 2,
#  'IDENTIFICATIONDETECTS': 1,
#  'KHOAGỢI': 1,
#  'ЭТИХ': 4,
#  'NOTEGRAM': 3,
#  'КОД2': 1,
#  'SRCMUSEOSCSERVERPYRUN': 1,
#  'POTRZEBA': 2,
#  'GUARDIAN': 11,
#  'STATUSES': 16,
#  'SCREENSACCOMPLISHMENTS': 1,
#  'HTTPWWWTHEATLANTICCOMTECHNOLOGYARCHIVE201408WHYEMAILWILLNEVERDIE375973THIS': 1,
#  'MINIATURE': 7,
#  'ANT': 4,
#  'CRONYBETWE': 1,
#  'ONINCASE': 1,
#  'ORGANISATION': 8,
#  'აქვს': 24,
#  'შვილის': 1,
#  'DOESASKS': 1,
#  'STATIXANDROID': 1,
#  'EGO': 1,
#  'BUCKETS': 6,
#  'LEARNEDDEPLOYING': 1,
#  'LEARNEDFIREBASE': 2,
#  'MICROSERVICE': 1,
#  'UTTAR': 3,
#  'CURRENCIES': 12,
#  'FRAMES': 40,
#  'SAFEDRIVE': 2,
#  'REHNUMA': 2,
#  'PPD42NS': 2,
#  'UPDATEOUR': 1,
#  'სლაიდზე': 5,
#  'TWIKIINSPIRATION': 1,
#  'SLAY': 1,
#  'BLINDSIDED': 2,
#  'POP•A•SHOP': 3,
#  'ЗВОНЯЩЕМУ': 1,
#  'EXTRACTS': 11,
#  'DUMPS': 1,
#  'WITHJAVAANDROIDSTUDIOECLIPSEESTIMOTECAMERALOVE': 1,
#  'ELECTRONICSWIRING': 1,
#  'WITHSWIFTOBJECTIVECXCODEPHOTOSHOPPAPERCOREMOTIONAUDIOTOOLKIT': 1,
#  'NEARBYIF': 1,
#  'ЧУДОВО': 1,
#  'COMFY': 1,
#  'ანონიმურად': 1,
#  'RECOMMENDING': 2,
#  'VANS': 4,
#  'MENUHEAVY': 1,
#  'რადგან': 14,
#  'CASES2': 1,
#  'DISORGANIZATION': 1,
#  'MANNYPAMINTUANORIGINALLY': 1,
#  'YOUGENIUSTHIS': 1,
#  'UNDEREXPLOITED': 1,
#  'TOMTOMMUSICIANS': 1,
#  'IMPRESSINGOFCOURSE': 1,
#  'EXPLORATION': 29,
#  'USERVIEW': 2,
#  'STRINGDEALING': 1,
#  'EFFERVESCENCE': 1,
#  'KUPIŁY': 1,
#  'КОНТАКТАМИ': 1,
#  'წარმომიდგა': 1,
#  'SLAYER': 1,
#  'ერთერთი': 8,
#  'ყოველი': 3,
#  'BETWEENTIME': 1,
#  'GREENFOOT': 1,
#  'THEFOLLOWING': 1,
#  'MUTTER': 1,
#  'CALM': 19,
#  'FILLING': 28,
#  'WALMARTCOM': 5,
#  'SPAMMED': 2,
#  'FLIR’S': 4,
#  'WITHLUA': 1,
#  'UNE': 21,
#  '10000SONG': 1,
#  '1230': 2,
#  'PROFITABILITY•': 1,
#  'BLUETOOTHNFC': 1,
#  'WATERLOOIF': 1,
#  'EDAWG878': 1,
#  'DEADDROPS': 1,
#  'HTTPWWWLUAORGABOUTHTML': 1,
#  'DETERMINISTIC': 1,
#  'WATCHLIST': 2,
#  'ADOBE': 23,
#  'RANKINGPARTICIPATING': 1,
#  'აპლიკაციები': 1,
#  'МИН': 1,
#  'დღიდან': 1,
#  'YUNS': 3,
#  'METROARM': 1,
#  'BUSINESSOUR': 1,
#  'REPOSTART': 1,
#  'წერექართულად': 2,
#  'გატეხვის': 1,
#  'THISCLICK': 1,
#  'DISEBABKAN': 2,
#  'MOUSEWHATS': 1,
#  'SUA': 2,
#  'SHE’LL': 2,
#  'HANDEDLY': 1,
#  'HTTPWWWGATIONLINERUINDEXPHPOPTIONCOMCONTENTVIEWARTICLEID76ITEMID100ЗНАКИВЫЗОВ': 1,
#  'TYLKO': 6,
#  'WITHGOOGLEMETRIXAPICXMLGRAPHTHEORY': 1,
#  'PACKETBUFFER15': 2,
#  'AFTERWARDS': 22,
#  'НЕОБХОДИМОСТЬ': 1,
#  'ESTABLECIDA': 1,
#  'IDEABUILDING': 1,
#  'INSTRUCTIONSAIM': 1,
#  'FULLYFLEDGED': 1,
#  'DISCOURAGED': 3,
#  'INVITE': 56,
#  'COINBASEVENMO': 1,
#  'CHOY': 1,
#  'DOWNFORWARDS': 1,
#  'OUTBUILT': 1,
#  'EXPLANATIONS': 5,
#  'WITHFLASKNUMPYOPENCVUNITYMETAEULERIANVIDEOMAGNIFICATIONWEBCAMPULSEDETECTOR': 1,
#  'GRANTED': 14,
#  'THETIME': 3,
#  'האקדמית': 1,
#  'WITHJAVASCRIPTAMAZONWEBSERVICES': 1,
#  'BACKENDANDROID': 1,
#  'OPTIONOUR': 1,
#  'COMPROMISEDBACKENDA': 1,
#  'SEVERN': 4,
#  'INSPIRATIONBRING': 1,
#  'BENEFITSWHY': 1,
#  'ENDPOINTS': 22,
#  '“BRING': 1,
#  'MEMBLE': 1,
#  'SHAREPUBLIC': 1,
#  'LOGARITHMIC': 1,
#  'DOCARDBOARD': 1,
#  'JAZZPOLLOUR': 1,
#  'დღეს': 3,
#  'BYŁ': 1,
#  'FOCUSED': 120,
#  'FACTORSTROVE': 1,
#  'PROPERLYHTTPSGYAZOCOM18ED9BD881265342853D59692FA00E4DHTTPSGYAZOCOM75F904F287B6780DD90C6976E4EDE9E8': 1,
#  'INSTANCEDATABASE': 1,
#  'POLITICSTECHNOLOGIES': 1,
#  'WEREINSPIRED': 1,
#  'ANALYSISEASY': 1,
#  'BACKGROUNDSACCOMPLISHMENTS': 1,
#  'ანდროიდი': 1,
#  'RANK': 27,
#  'SENCILLO': 2,
#  'BUGები': 1,
#  'PRIVACYSMASHER': 1,
#  'INTIATES': 1,
#  'MYUK': 1,
#  'SOFTWAREAND': 1,
#  'CHIRPING': 1,
#  'SEISMOGRAPH': 1,
#  'CLICK24': 1,
#  'SYNCHRONICITY': 1,
#  'ПОЛЕЗНЫМ': 1,
#  'სახსარზე': 1,
#  'NASZ': 4,
#  'SAYS': 22,
#  'PROCRASTINATES': 1,
#  'O1': 1,
#  'GPSGSM': 1,
#  'ANYTIMEAND': 1,
#  'THIRUVENGADAM': 1,
#  'ARRESTS': 3,
#  'BIRD’S': 1,
#  'GLIMMER': 1,
#  'LEARNEDQUE': 2,
#  'ქალაქში': 2,
#  'COMEBACKSTHE': 1,
#  'CARDINAL': 1,
#  'KESETARAAN': 1,
#  'THERMA': 2,
#  'EYESBABBLIOMUS': 1,
#  'FRIENDSHIPCHALLENGES': 1,
#  'TODAYPRIVACYYOUR': 1,
#  'DATATEAM': 1,
#  'APITM': 2,
#  'ALERTS3': 1,
#  'HANDYWHAT': 1,
#  'CLICKSHOMERUN': 1,
#  'LGA': 1,
#  'IMBIBED': 1,
#  'INTOONE': 27,
#  'AVAILABLEDRIVERS': 1,
#  'PLANINGGITHUB': 1,
#  'INSPIRATIONSFU': 1,
#  'DINNER': 26,
#  'CHECKPOINT': 2,
#  'CLOUDFORMATION': 2,
#  'BELLABEAT': 2,
#  'ბავშვთა': 1,
#  'FAQ': 1,
#  'XMEN': 1,
#  'CRISES': 4,
#  'HTTPSDOCSGOOGLECOMPRESENTATIOND1CAOIKHOEXWSZJP7IADKZCKLFDGFJFEQJSLLCXZPAEDITUSPSHARING': 1,
#  'DEADLINES': 10,
#  'CANADAWHAT': 1,
#  'INTOEACH': 2,
#  'TARDADO': 1,
#  'AUDITIONING': 4,
#  'SETUPS': 2,
#  'ACCOUNTSHOW': 1,
#  'STRANGE': 12,
#  'THESERESOURCESAPI': 1,
#  'ONEOFAKIND': 1,
#  'ASPHYXIATED': 1,
#  'INSPIRATIONRIDE': 1,
#  'YOUMORE': 1,
#  'ORGANIZATIONIF': 1,
#  'BURNEDWHY': 1,
#  'LOCATIONJ': 8,
#  'PRERENT': 1,
#  'ENDORSED': 1,
#  'EPISODES': 7,
#  'HUSKIE': 1,
#  'SIGNUP': 17,
#  'დიშვილების': 1,
#  'RUNMATEWE': 1,
#  'CALLE': 4,
#  '124': 1,
#  'TRUPARK': 1,
#  'ყველასთვის5ფულის': 1,
#  'ACCUMULATIVE': 1,
#  'SAVER': 14,
#  'DHOW': 1,
#  'PHASE': 50,
#  'SNO': 3,
#  'JOGGER': 1,
#  'NUMBER”': 1,
#  'STAGNATIONTHE': 1,
#  'APK': 19,
#  'CAMPUSWIDE': 1,
#  'LUGAR': 11,
#  'TRADERS': 6,
#  'LEARNEDROR': 1,
#  'TENEMAZAMINUL': 1,
#  'TIEMPORECORDAR': 1,
#  'HTTPYOUTUBEGSPNXPEHSET2H22M4S': 1,
#  'MAXIMALLY': 2,
#  'ДОХОДЫ': 1,
#  'TOUCHBASED': 1,
#  'PRANKSPAM': 1,
#  'PROFESSIONALSTHE': 2,
#  'CONTRACTS…': 1,
#  'PHONESADD': 1,
#  'EXPANDS': 9,
#  'PEQUEÑA': 1,
#  'სერვერზეPHP': 1,
#  'READERS）': 1,
#  'COLLECTIONMORE': 1,
#  'CONQUERKNOWLEDGE': 1,
#  'ITDIVIDING': 1,
#  'AUDITORY': 16,
#  'LEARNNATURAL': 1,
#  'PEDIATRICS': 4,
#  'DOMESTIK': 1,
#  'FUNDESPITE': 1,
#  'დავრჩით': 1,
#  'WITHLIBRARIESPYTHONIBM': 1,
#  'RECD': 3,
#  'REVIEWCOLD': 1,
#  'IDENTICAL': 3,
#  'DARLE': 3,
#  'ONESELF': 1,
#  'BURST': 1,
#  'OFKATHLEENDESIGNING': 1,
#  'მსხვერპლი': 1,
#  'РЕАЛЬНЫХ': 1,
#  'LIQUIDCRYSTALHINCLUDE': 3,
#  'SCOTT': 2,
#  'USERSWITHIN': 1,
#  'APISLOWLEVEL': 1,
#  'ALGORITMO': 3,
#  'WITHHTML5CSSJAVASCRIPTGOOGLEJQUERYINVISIONDESIGNSOFTWARE': 1,
#  'EVERLASTING': 1,
#  'TOENTER': 1,
#  'GERMANY': 15,
#  'НЕЗАРЕЄСТРОВАНОГО': 1,
#  'MENGALIRKERINGPENGGUNA': 1,
#  'INCONSEQUENTIAL': 2,
#  'TRIANGULATION': 4,
#  'NARRATIVEWE': 1,
#  'WHOMANY': 1,
#  'EVENTFUL': 4,
#  'SENDSMSCHOREOBEGIN': 2,
#  'CHATWHICH': 1,
#  'VIRTUOUS': 1,
#  'XXXXX': 1,
#  'MENGALAMI': 8,
#  'ACADMEIC': 1,
#  'CRUDE': 7,
#  'PAGEACCOMPLISHMENTS': 2,
#  'UPDATERDEVELOPING': 1,
#  'INPUTSWHAT': 2,
#  'CURRENTS': 3,
#  'SE': 145,
#  'PIRREMENTORSJIN': 1,
#  'CONSOLEBASED': 1,
#  'FEATURESBODY': 1,
#  'NACISNĄĆ': 1,
#  'SPONTIVITIES': 5,
#  'FOLDERSOLUTION': 1,
#  'WEEKENDWELL': 1,
#  'ხელი': 2,
#  'ააჩქარებს': 1,
#  'FILTERSELECT': 1,
#  'DEFAULTHTML': 1,
#  'APPEALINGCREATE': 1,
#  'STAKEHOLDERS': 13,
#  'თამაშებში': 1,
#  'DETAILSTENDR': 1,
#  'VIDAQUÉ': 1,
#  'HUMMERSPRADIER': 1,
#  'WEARABLESWHATS': 3,
#  'DEPLOYS': 2,
#  'USABILITY': 15,
#  'ZOMBIE': 26,
#  'WITHSOLDERINGEQUIPMENTWIRESLEDSMYBRAIN555TIMERS2N3904': 1,
#  'TELEGRAM': 6,
#  'BUILDS': 29,
#  'ITTRIPPY': 1,
#  'RISKFOR': 1,
#  'VCARD': 3,
#  'PINNED': 10,
#  'MINIMUMNOWTHE': 2,
#  'GPSBUZZI': 1,
#  'LIVEUPDATING': 3,
#  'НЕБОЛЬШИМ': 1,
#  '0643': 1,
#  'ALGONQUIN': 2,
#  'USERGROUP': 1,
#  'QS': 1,
#  'TALENTVOICE': 1,
#  'ILLUMINATED': 2,
#  'INEXPERIENCED': 4,
#  'ЧАСА': 1,
#  'SUBSTANCE': 3,
#  'USERSADDNEW': 1,
#  'SHOPS': 40,
#  '072': 3,
#  'IDEASTHE': 2,
#  'TREATMENTS': 12,
#  'IPADS': 5,
#  'SUPSTEP': 1,
#  'WORKINGACCOMPLISHMENTS': 3,
#  'OCULUSRIFT': 1,
#  'ANYWHEREUNLIKE': 1,
#  'DOORBELLS': 1,
#  '073': 1,
#  'MOTORSSETRIGHTSPEED300': 3,
#  'VISUALIZATION': 182,
#  'PAULS': 2,
#  '302': 1,
#  'PLANTSTHE': 1,
#  'HTTPS': 4,
#  'ENDPOINTSREPLY': 1,
#  'COLLEGECAB': 1,
#  'INVOICING': 2,
#  'POPSICLE': 7,
#  'გაანალიზება': 1,
#  'OVERSEA': 1,
#  'IMPROVEASK': 1,
#  'ACCELERATIONX': 1,
#  'MARGINALISATION': 1,
#  'USCORS': 1,
#  'FUTURETV': 1,
#  'OTHERFEEDBACK': 1,
#  'PLAYEDTHE': 1,
#  'SKIES3': 1,
#  'APPSAFTER': 1,
#  'PREFERENCESORDER': 1,
#  'SOLIDIFY': 4,
#  'NAPISANA': 1,
#  'STRESSWHATS': 1,
#  'DELIVERING': 26,
#  'SMILEHOW': 1,
#  '“OFFTHEGRID”': 2,
#  'SNOWBOARDING': 3,
#  'ANYMORE': 26,
#  'VILLE': 6,
#  'BUENA': 3,
#  'VIOLA': 1,
#  'QRCODES': 4,
#  'ADVISABLE': 2,
#  'სითბოსგან': 1,
#  'FIRSTS': 2,
#  'SCALABLE2': 1,
#  'CÓDIGOWHATS': 1,
#  'GREATNESS”': 1,
#  'PLAINTE': 2,
#  'LIKELIHOODS': 1,
#  'KEYWORD': 35,
#  'COURSEWE': 1,
#  '247': 8,
#  'BUSING': 1,
#  'PACETHE': 1,
#  'TEETH': 7,
#  '“POPULATIONS”': 1,
#  'HTMLVICTOR': 1,
#  'HACKATUNE': 2,
#  'ALLWE': 1,
#  'RARELY': 22,
#  'SUBJECT': 66,
#  'INCLUDE1': 1,
#  'COMPARTILHAM': 1,
#  'CONVENCIDOS': 1,
#  'FRANKE': 1,
#  'HSR54გამშლელდამხვევი': 1,
#  'GIVE': 577,
#  'ANTENATAL': 2,
#  'MIRATELE': 1,
#  'ABLEDTHIS': 1,
#  'PODIA': 1,
#  'ISOLATED': 17,
#  'HTTPWWWSLIDESHARENETSLIDESHOWEMBEDCODE44983555': 1,
#  'INSPIRATIONTHERES': 3,
#  'ANNOUNCER': 1,
#  'DJFINDING': 1,
#  'ADJUST': 57,
#  'LUCKIER': 1,
#  'LINKTEAM': 1,
#  'REACHING': 37,
#  'NIC': 5,
#  'POSITIVA': 1,
#  'PARTICIPIN': 1,
#  'ASSEMBLED': 15,
#  'ANTEATERS': 1,
#  'LIGAMENT': 1,
#  'უორმაგებს': 1,
#  'PERIODICALLYTHE': 1,
#  'COLLECTION': 94,
#  'WITHUNITYMYOCONNECTMYO': 1,
#  'ENCRYPTIONCHALLENGES': 1,
#  'WAVEUP': 1,
#  'EMERGENCY': 281,
#  'DEVELOPMENTPRINCE': 1,
#  'PERCEPTIVE': 1,
#  'COLORTEMPERATURE': 1,
#  'POINTTRANSLATION': 1,
#  'FINISHINGWHAT': 1,
#  'ANIMATIONWHATS': 1,
#  'SIMPLEFORMFORME': 1,
#  'BOOKINGSINCE': 1,
#  'დაკავშირებისრა': 1,
#  'GEOMETRIC': 3,
#  'INSPIRATIONCUTE': 1,
#  'SUPPLEMENTAL': 4,
#  'RECOMMENDEDTHIS': 1,
#  'კოეფიციენტის': 1,
#  'EVERYTHINGTHATS': 1,
#  'CONCLUSIÓN': 1,
#  'იქნებოდნენ': 1,
#  'დამზადებულია': 1,
#  'UTILIZADAS': 1,
#  'FINDER': 16,
#  'TEAMAYO': 1,
#  'DESENVOLVEDORACCOMPLISHMENTS': 1,
#  'WAYPOINT': 2,
#  'WEBSITEWE': 3,
#  'HARDENED': 1,
#  '2013LOCATIONBASEDEVERY': 1,
#  'MONETYZACJI': 1,
#  'აუცილებელი': 2,
#  'SIGHTSNOT': 1,
#  'POSTGET': 1,
#  'MULTITASK': 3,
#  'VOIDWHAT': 1,
#  'SLEUTH': 1,
#  'EXTREAM': 1,
#  'DEMONSTRABLE': 1,
#  'LINE': 194,
#  'ACHALANDAGE': 1,
#  'TRIỂN': 2,
#  'WITHAPIJAVASCRIPTPHPHTMLMOZILLACSSNOTEPADLINUXXAMPP': 1,
#  'დატენვასთან': 1,
#  'DATASTORE': 7,
#  'SHOREALL': 1,
#  'PERO': 23,
#  'APOPTOSIS': 1,
#  'DINERS': 4,
#  'FACILITYHOW': 1,
#  'FITTING': 22,
#  'HTTPSGITHUBCOMDREAMFORCEHACKATHONREPOSITORY255APP': 1,
#  'MDF': 1,
#  'DEVICESMULTILINGUAL': 1,
#  'WEBSITES': 143,
#  'ABOUTXCELMAIL': 1,
#  'MIDLEVEL': 1,
#  'SERVICESKEY': 1,
#  'COMPANIESWE': 1,
#  'ISDROPPING': 1,
#  'LIGHTLYHACKWATERLOO': 1,
#  'TELL': 210,
#  'TOOWO': 1,
#  'POSSIBLEIT': 1,
#  'ADRESS': 1,
#  'WITHPLAYGOOGLEMAPSGOOGLEDISTANCEMATRIX': 1,
#  'TRIPABILITY': 1,
#  'USESNOTE': 1,
#  'მიუთითებს': 1,
#  'IMPERFECT': 2,
#  'REALTIMEACCOMPLISHED': 1,
#  'DODATKOWYCH': 1,
#  'CHAIR': 38,
#  'UNEQUAL': 2,
#  'WITHANDROIDECLIPSE': 2,
#  'AGAINMASTERMINDMASTERMIND': 1,
#  'LOWBANDWIDTH': 1,
#  'LATERSHARE': 1,
#  'ZOMBLRWE': 1,
#  'STANDPOINT': 4,
#  'ANDNETWORK': 1,
#  '«MIROIR': 7,
#  '6PM10PM': 1,
#  'SIGNIFICANTLYWE': 1,
#  'NAMEAND': 1,
#  'HIGHSECURITY': 1,
#  'BTSERIAL5': 1,
#  'SKATER': 1,
#  'TOCOMBINING': 1,
#  'STATIONSBIG': 1,
#  'WITHTEXTBLOBPYTHONNATURALLANGUAGEPROCESSING': 1,
#  'YOO': 1,
#  'TEENSY': 3,
#  '900MHZ': 1,
#  'HOLLER': 1,
#  'FLASHCARDLIKE': 1,
#  'ASHLEY': 1,
#  'NATIVA': 1,
#  'PRODUCTTHESE': 1,
#  'MATH239': 3,
#  'TRANSACT': 1,
#  'AREAUSERS': 1,
#  'CHOOSEYOU': 1,
#  'CONCERN': 37,
#  'LANDLORDSOWNERS': 1,
#  'DIVERT': 1,
#  'SUPPLIED': 10,
#  'H': 11,
#  'IMPLICATIONS': 14,
#  'OFTHINGS': 1,
#  'TRANSACTION2': 1,
#  'NEWS': 275,
#  'SHAREWILL': 1,
#  'ITI': 78,
#  'DOCEDUCATION': 1,
#  'EXTRAVERSION': 1,
#  'HOOLI': 1,
#  'უზრუნველყობს': 1,
#  'თარგმანში': 1,
#  ...}

# %%
word_order_dict = {}
words_counted = [word for word in word_count_dict.keys() if word_count_dict[word] > 10]
len(words_counted)
# Out:
# 3670

# %%
words_counted = sorted(words_counted)
num_words = len(words_counted)

# %%
for i in range(0, len(words_counted)):
    word_order_dict[words_counted[i]] = i

# %%
def transform_winner(winner):
    if(winner):
        return 1
    else:
        return 0

# %%
data_output = []
for project in projects:
    word_vec = [0] * num_words
    words = transform_blob(project['description']).split(' ')
    for word in words:
        if word in word_order_dict:
            word_vec[word_order_dict[word]] += 1
    
    data_output.append({
            'hackathon_id': project['hackathon_id'],
            'winner': transform_winner(project['winner']),
            'word_vec': word_vec
        })

# %%
with open('./scrape_data/data_output.json', 'w') as f:
    json.dump(data_output, f)

# %%
class PassageVectorizer():
    def __init__(self):
        with open('./scrape_data/projects.json','r') as f:
            projects = json.load(f)
            
        word_count_dict = {}
        for project in projects:
            desc = self.transform_blob(project['description'])
            words = desc.split(' ')
            for word in words:
                if word in word_count_dict:
                    word_count_dict[word] += 1
                else: 
                    word_count_dict[word] = 1
        word_order_dict = {}
        words_counted = [word for word in word_count_dict.keys() if word_count_dict[word] > 10]
        words_counted = sorted(words_counted)
        self.num_words = len(words_counted)
        for i in range(0, len(words_counted)):
            word_order_dict[words_counted[i]] = i
            
        self.word_order_dict = word_order_dict
    
    def transform_blob(self, blob):
        exclude = set(string.punctuation)
        t_blob = ''.join(ch for ch in blob if ch not in exclude)
        t_blob = t_blob.replace('\n','')
        t_blob = t_blob.replace('  ',' ')
        t_blob = t_blob.upper()
        return t_blob
    
    def transform_winner(self, winner):
        if(winner):
            return 1
        else:
            return 0
        
    def vectorize_passage(self, passage):
        data_output = []
        word_vec = [0] * self.num_words
        words = self.transform_blob(passage).split(' ')
        for word in words:
            if word in self.word_order_dict:
                word_vec[self.word_order_dict[word]] += 1

        return word_vec

# %%
pv = PassageVectorizer()

# %%
with open('../server/passage_vectorizer.pkl','wb') as f:
    pickle.dump(pv, f)
